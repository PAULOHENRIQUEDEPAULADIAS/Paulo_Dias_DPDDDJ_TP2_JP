# %% [markdown]
# <h1 style="text-align: center;">TP2 - Design Patterns e Domain-Driven Design (DDD) com Java</h1>

# %% [markdown]
# | ![Logo Infnet](https://mir-s3-cdn-cf.behance.net/projects/404/9115f025917929.5547cdc9cda40.jpg) |
# |:-------------------------------------------------------------------------:|

# %% [markdown]
# <h5 style="text-align: center;">Professor: Armênio Cardoso || Estudante: Paulo Henrique de Paula Dias</h5>

# %% [markdown]
# <h5 style="text-align: center;">Data limite: 25/08/2025</h5>

# %% [markdown]
# # Orientações

# %% [markdown]
# Neste teste, é apresentado um estudo de caso que precisa ser elaborado.
#
# No contexto do Domain Driven Design, os domínios e subdomínios do negócio do McDonald's podem incluir:

# %% [markdown]
# **Gestão de Alimentos e Bebidas:**
# * Gestão de cardápio.
# * Controle de estoque de alimentos e bebidas.
#
# **Gestão de fornecedores:**
# * Operações de Restaurante.
# * Gestão de pedidos.
# * Preparação de alimentos.
# * Atendimento ao cliente.
# * Limpeza e manutenção do restaurante.
#
# **Vendas e Marketing:**
# * Estratégias de marketing.
# * Gestão de promoções e ofertas.
# * Gestão de pedidos online e aplicativos móveis.
#
# **Gestão de Franquias:**
# * Relações com franqueados.
# * Treinamento e suporte.
# * Contratos e regulamentos.
#
# **Tecnologia da Informação:**
# * Desenvolvimento de software interno.
# * Infraestrutura de TI.
# * Segurança da Informação e Proteção de Dados.
#
# **Logística e Cadeia de Suprimentos:**
# * Distribuição de alimentos e suprimentos.
# * Gerenciamento de transporte.
# * Armazenamento e gestão de inventário.
#
# **Finanças e Contabilidade:**
# * Contabilidade geral.
# * Gestão de despesas e receitas.
# * Relatórios financeiros.
#
# **Recursos Humanos e Gestão de Pessoas:**
# * Recrutamento e seleção.
# * Treinamento de funcionários.
# * Gestão de folha de pagamento e benefícios.

# %% [markdown]
# #### Considerando esse cenário apresentado, pesquisando mais dados e usando a sua vivência como consumidor, elabore um documento com as seguintes seções:
#
# * Descrição resumida do Domínio de Negócio.
# * Lista completa de Subdomínios classificados como core, supporting ou generic (justifique a sua classificação do lado de cada item da lista e acrescente algum item que ache que está faltando).
# * Identificação dos Bounded Contexts com um conjunto resumido de entidades que compõem cada contexto.

# %% [markdown]
# # Resolução

# %% [markdown]
# ### Descrição resumida do Domínio de Negócio.

# %% [markdown]
# No contexto da empresa McDonald's, seu domínio de negócio está diretamente relacionado na industria de alimentação rápida, caracterizado pela padronização de processos, rapidez no atendimento e preparo dos alimentos. Suas atividades englobam:
#
# 1. Manuseio e preparo de alimentos processados, como hamburgers, pães para hamburgers, molhos, etc, e alimentos não processados, como alface, tomate, cebola, etc, e;
#
# 2. Cocção de alimentos processados como grelhar e fritar.
#
# Nesse contexto, o Domínio de Negócios do McDonald's está envolto na indústria de serviços de refeições rápidos, combinando logística de fornecimento, operações de preparo e comercialização em escala global.

# %% [markdown]
# ### Lista completa de Subdomínios classificados como core, supporting ou generic (justifique a sua classificação do lado de cada item da lista e acrescente algum item que ache que está faltando).

# %% [markdown]
# OBS: Para tal classificação, tomei de base a visão estratégica McDonald's, isso significa que as classificações foram baseadas na visão de auto escalão empresarial, trazendo máximo retorno financeiro.

# %% [markdown]
# Abaixo trago os termos classificados e suas definições.

# %% [markdown]
# ![image.png](attachment:82f98302-a3dd-47fb-8714-0c25ad4caaa2.png)

# %% [markdown]
# Abaixo trago os termos classificados e suas respectivas justificativas

# %% [markdown]
# ![image.png](attachment:1bde2c77-4cdb-4619-a9a4-3a9ba5ab3cff.png)

# %% [markdown]
# ### Identificação dos Bounded Contexts com um conjunto resumido de entidades que compõem cada contexto.

# %% [markdown]
# Abaixo trago bounded context com seus conjuntos de entidades resumidas.

# %% [markdown]
# ![image.png](attachment:f616bcbd-a188-4386-a18a-9b30768ec6e9.png)
